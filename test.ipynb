# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 查找四大指數

# %%
url="https://histock.tw/%E5%9C%8B%E9%9A%9B%E8%82%A1%E5%B8%82"

# %%
resp=requests.get(url)

# %%
resp.text
# Out:
# '\r\n \r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n<meta http-equiv="Content-Language" content="zh-tw"/>\r\n<meta name="robots" content="index,follow" />\r\n<meta name="googlebot" content="index,follow" />\r\n<meta http-equiv="refresh" content="480; url=https://histock.tw/國際股市" />\r\n<meta name="keywords" content="國際股市指數, 全球股市, 匯率, 台灣指數, 美洲股市, 亞洲股市, 歐洲股市, 國際期貨, 金屬, 能源, 農產品, 原物料, 波羅的海航運, ADR" />\r\n<meta property="og:title" content="國際股市指數 全球股市" />\r\n<meta name="description" property="og:description" content="最專業即時的國際股市指數報價, 免費提供全球股市休市, 以及台股分類、重點股市等常用資料, 還有匯率, 台灣指數、美洲股市、ADR、亞洲股市、歐洲股市、國際期貨、金屬、能源、農產品、原物料、波羅的海航運、績效排行等即時行情報價" />\r\n<meta name="application-name" content="HiStock嗨投資理財社群"/>\r\n<meta property="og:url" content="htt
# ...

# %%
soup =BeautifulSoup(resp.text,"lxml")
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="zh-tw" http-equiv="Content-Language"/>
# <meta content="index,follow" name="robots"/>
# <meta content="index,follow" name="googlebot"/>
# <meta content="480; url=https://histock.tw/國際股市" http-equiv="refresh"/>
# <meta content="國際股市指數, 全球股市, 匯率, 台灣指數, 美洲股市, 亞洲股市, 歐洲股市, 國際期貨, 金屬, 能源, 農產品, 原物料, 波羅的海航運, ADR" name="keywords"/>
# <meta content="國際股市指數 全球股市" property="og:title"/>
# <meta content="最專業即時的國際股市指數報價, 免費提供全球股市休市, 以及台股分類、重點股市等常用資料, 還有匯率, 台灣指數、美洲股市、ADR、亞洲股市、歐洲股市、國際期貨、金屬、能源、農產品、原物料、波羅的海航運、績效排行等即時行情報價" name="description" property="og:description"/>
# <meta content="HiStock嗨投資理財社群" name="application-name"/>
# <meta content="https://histock.tw/index" property="og:url"/>
# ...

# %%
soup.find("div",class_="index-list")
# Out:
# <div class="index-list"><table class="tb-index-list"><tr id="JNM"><td class="idn"><a href="/index/JNM" target="_blank">小日經</a></td><td class="clr-r" id="JNM_P">39570.0</td><td class="clr-r" id="JNM_C">▲1040.0</td><td class="clr-r" id="JNM_R">▲2.70%</td><td class="idt" id="JNM_T">06:00</td></tr><tr id="HMH"><td class="idn"><a href="/index/HMH" target="_blank">小恆生</a></td><td class="clr-g" id="HMH_P">22609.0</td><td class="clr-g" id="HMH_C">▼265.0</td><td class="clr-g" id="HMH_R">▼1.16%</td><td class="idt" id="HMH_T">02:59</td></tr><tr id="CSI300"><td class="idn"><a href="/index/CSI300" target="_blank">滬深300</a></td><td class="clr-r" id="CSI300_P">4017.9</td><td class="clr-r" id="CSI300_C">▲314.2</td><td class="clr-r" id="CSI300_R">▲8.48%</td><td class="idt" id="CSI300_T">15:00</td></tr><tr id="SZSE"><td class="idn"><a href="/index/SZSE" target="_blank">深圳綜合</a></td><td class="clr-r" id="SZSE_P">1927.5</td><td class="clr-r" id="SZSE_C">▲189.9</td><td class="clr-r" id="SZSE_R">▲10.93%</
# ...

# %%
trs=soup.find(string="小日經" ).find_parent("div").find_all("tr")
trs
# Out:
# [<tr id="JNM"><td class="idn"><a href="/index/JNM" target="_blank">小日經</a></td><td class="clr-r" id="JNM_P">39570.0</td><td class="clr-r" id="JNM_C">▲1040.0</td><td class="clr-r" id="JNM_R">▲2.70%</td><td class="idt" id="JNM_T">06:00</td></tr>,
#  <tr id="HMH"><td class="idn"><a href="/index/HMH" target="_blank">小恆生</a></td><td class="clr-g" id="HMH_P">22609.0</td><td class="clr-g" id="HMH_C">▼265.0</td><td class="clr-g" id="HMH_R">▼1.16%</td><td class="idt" id="HMH_T">02:59</td></tr>,
#  <tr id="CSI300"><td class="idn"><a href="/index/CSI300" target="_blank">滬深300</a></td><td class="clr-r" id="CSI300_P">4017.9</td><td class="clr-r" id="CSI300_C">▲314.2</td><td class="clr-r" id="CSI300_R">▲8.48%</td><td class="idt" id="CSI300_T">15:00</td></tr>,
# ...

# %%
datas=[]
for tr in trs:
    data=[]
    for th in tr.find_all("th"):
        print(th.text.strip(),end="\t")
    for td in tr.find_all("td"):
        print(td.text.strip(), end="\t")
        data.append(td.text.strip())
    datas.append(data)
    print()
datas
# Out:
# 小日經	39570.0	▲1040.0	▲2.70%	06:00
# 小恆生	22609.0	▼265.0	▼1.16%	02:59
# 滬深300	4017.9	▲314.2	▲8.48%	15:00
# 深圳綜合	1927.5	▲189.9	▲10.93%	15:00
# 比特幣	61901.0	▼187.0	▼0.30%	01:02
# 以太幣	2413.5	▲7.9	▲0.33%	01:03
# [['小日經', '39570.0', '▲1040.0', '▲2.70%', '06:00'],
#  ['小恆生', '22609.0', '▼265.0', '▼1.16%', '02:59'],
#  ['滬深300', '4017.9', '▲314.2', '▲8.48%', '15:00'],
#  ['深圳綜合', '1927.5', '▲189.9', '▲10.93%', '15:00'],
#  ['比特幣', '61901.0', '▼187.0', '▼0.30%', '01:02'],
#  ['以太幣', '2413.5', '▲7.9', '▲0.33%', '01:03']]

# %% [markdown]
# ### PM25 資料查詢

# %%
URL = "https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate%20desc&format=JSON"

# %%
datas=requests.get(URL).json()["records"]
datas
# Out:
# [{'sitename': '基隆',
#   'county': '基隆市',
#   'aqi': '24',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.1',
#   'co': '0.18',
#   'o3': '18.1',
#   'o3_8hr': '26.6',
#   'pm10': '8',
#   'pm2.5': '2',
#   'no2': '5.7',
#   'nox': '6.3',
#   'no': '0.6',
#   'wind_speed': '0.5',
#   'wind_direc': '77',
#   'publishtime': '2024/10/17 22:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6.8',
#   'pm10_avg': '16',
#   'so2_avg': '1',
#   'longitude': '121.760056',
#   'latitude': '25.129167',
#   'siteid': '1'},
#  {'sitename': '汐止',
#   'county': '新北市',
#   'aqi': '25',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.19',
#   'o3': '9.8',
#   'o3_8hr': '',
#   'pm10': '18',
#   'pm2.5': '8',
#   'no2': '15.5',
#   'nox': '16.9',
#   'no': '1.4',
#   'wind_speed': '0.4',
#   'wind_direc': '47',
#   'publishtime': '2024/10/17 22:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '7.8',
#   'pm10_avg': '15',
#   'so2_avg': '0',
#   'longitude': '121.64081',
# ...

# %%
for data in datas:
    print(data["sitename"],data["pm2.5"])
# Out:
# 基隆 2
# 汐止 8
# 萬里 4
# 新店 7
# 土城 2
# 板橋 0
# 新莊 10
# 菜寮 4
# 林口 6
# 淡水 10
# 士林 2
# 中山 10
# 萬華 7
# 古亭 6
# 松山 8
# 大同 10
# 桃園 6
# 大園 11
# 觀音 9
# 平鎮 4
# 龍潭 4
# 湖口 15
# 竹東 10
# 新竹 7
# 頭份 15
# 苗栗 16
# 三義 20
# 豐原 19
# 沙鹿 23
# 大里 32
# 忠明 22
# 西屯 17
# 彰化 22
# 線西 16
# 二林 17
# 南投 34
# 斗六 34
# 崙背 28
# 新港 32
# 朴子 30
# 臺西 15
# 嘉義 24
# 新營 25
# 善化 34
# 安南 27
# 臺南 26
# 美濃 18
# 橋頭 27
# 仁武 25
# 鳳山 23
# 大寮 23
# 林園 20
# 楠梓 23
# 左營 17
# 前金 15
# 前鎮 21
# 小港 25
# 屏東 22
# 潮州 16
# 恆春 4
# 臺東 5
# 花蓮 6
# 陽明 0
# 宜蘭 2
# 冬山 5
# 三重 11
# 中壢 7
# 竹山 37
# 永和 7
# 復興 22
# 埔里 36
# 馬祖 15
# 金門 26
# 馬公 8
# 關山 1
# 麥寮 13
# 富貴角 4
# 大城 10
# 彰化（員林）
# 高雄（湖內） 25
# 臺南（麻豆） 23
# 屏東（琉球） 12
# 新北(樹林) 4
# 宜蘭（頭城） 3
# 屏東(枋山) 3
